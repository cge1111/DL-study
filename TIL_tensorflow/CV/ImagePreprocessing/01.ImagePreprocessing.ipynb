# %%
import tensorflow as tf
import numpy as np

import pandas as pd
import cv2
import os
import math
import scipy as sp
import PIL

# Tensorflow
from tensorflow.keras import models, layers, Model
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout, ZeroPadding2D

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import EfficientNetB4, EfficientNetB6, ResNet50V2
#from keras_tuner.tuners import RandomSearch

import scikitplot as skplt
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
# tf.__version__

# %%
# pip install scikit-plot  
# pip install opencv-python   # cv

# %% [markdown]
# # 1. keras - load_img
#
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/load_img

# %%
Image = tf.keras.utils.load_img(
    'SkinCancer/TRAIN/akiec/ISIC_0024372.jpg',
    grayscale=False,
    color_mode='rgb',
    target_size=None,
    interpolation='nearest',
    # keep_aspect_ratio=True
)

# %%
Image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x112205520>

# %%
type(Image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# # image to numpy array conversion

# %%
image_array = tf.keras.preprocessing.image.img_to_array(Image)

# %%
type(image_array)
# Out:
# numpy.ndarray

# %%
image_array.shape
# Out:
# (450, 600, 3)

# %%
image_array[:, :, 1] # green
# Out:
# array([[ 89.,  92.,  93., ..., 142., 143., 141.],
#        [ 86.,  90.,  94., ..., 141., 142., 139.],
#        [ 83.,  86.,  91., ..., 139., 140., 140.],
#        ...,
#        [122., 121., 122., ..., 149., 150., 150.],
#        [122., 122., 124., ..., 150., 149., 150.],
#        [123., 124., 126., ..., 147., 146., 147.]], dtype=float32)

# %%
# Image는 0 ~ 1 사이 값이어야 plot이 가능함

plt.imshow(image_array, interpolation='nearest')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# image_array[:,:,0] = 0

# %%
# Image는 0 ~ 1 사이 값이어야 plot이 가능함

plt.imshow(image_array / 255, interpolation='nearest')
plt.show()

# %%
# RGB / Red image

plt.imshow(image_array[:,:,0] / 255, interpolation='nearest', cmap='gray')
plt.show()

# %%
# RGB / Green image

plt.imshow(image_array[:,:,1] / 255, interpolation='nearest', cmap='gray')
plt.show()

# %%
# RGB / Blue image

plt.imshow(image_array[:,:,2] / 255, interpolation='nearest', cmap='gray')
plt.show()

# %%
image_array[50:400, 100,:] = 255

# %%
# 정사각형이 아닐경우 사이즈 조정을 위 많이 사용함

CropImage = image_array[50:400, 100:400,:]
plt.imshow(CropImage/255, interpolation='nearest')
plt.show()

# %%
# RGB / Blue image

plt.imshow(image_array / 255, interpolation='nearest')
plt.show()

# %%
image_array[50:400, 450,:] = 255

# RGB / Blue image

plt.imshow(image_array / 255, interpolation='nearest')
plt.show()

# %%
image_array[50:60, 100:450,:] = 255

# RGB / Blue image

plt.imshow(image_array / 255, interpolation='nearest')
plt.show()

# %%
image_array[400:410, 100:450,:] = 255

# RGB / Blue image

plt.imshow(image_array / 255, interpolation='nearest')
plt.show()
